# %% [markdown]
# # Task 3

# %%
from scipy import misc
import matplotlib.image as img
import scipy.ndimage as ndimage
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os
from skimage.data import data_dir
from skimage import io
from skimage import util 
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import feature

image = io.imread(os.path.join(data_dir, "sun.png"), as_grey=True)

noisy = util.random_noise(image, mode='s&p', seed=None, clip=True)

im_med = ndimage.median_filter(noisy, 3)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,10))
plt.subplot(141)
plt.imshow(image,cmap = plt.get_cmap('gray'))
plt.subplot(142)
plt.imshow(noisy,cmap = plt.get_cmap('gray'))
plt.subplot(143)
plt.imshow((image-im_med), cmap='gray')
plt.subplot(144)
plt.imshow((image-noisy), cmap='gray')






plt.show()
